# %%
import time # for calculation of times
import numpy as np # for efficient list
import pandas as pd # for efficient tables
from matplotlib import pyplot as plt # for visualization
import seaborn as sns # for visualization
from mlxtend.frequent_patterns import apriori # machine learning xtend tool for apriori algorithm
from mlxtend.frequent_patterns import association_rules # machine learning xtend tool for association rules
from mlxtend.frequent_patterns import fpgrowth # machine learning xtend tool for fp growth algorithm

# %%
plt.style.use('fivethirtyeight')

# %%
path = 'groceries.txt'
f = open(path, 'r') # opening file pointer and reading from path in only read mode

data = [] 
for line in f.readlines(): # iterating each line from file
    l = line.split(',') # spliting each line by ',' seperater
    l = l[:-1:1] # skipping last element of list which is -> '\n'
    if l != []:
        data.append(l)
f.close() # closing file pointer
data
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine'],
#  ['tropical fruit', 'yogurt'],
#  ['pip fruit', 'yogurt', 'cream cheese'],
#  ['other vegetables', 'whole milk', 'condensed milk'],
#  ['whole milk', 'butter', 'yogurt', 'rice'],
#  ['other vegetables', 'UHT-milk', 'rolls/buns', 'bottled beer'],
#  ['whole milk'],
#  ['tropical fruit', 'other vegetables', 'white bread', 'bottled water'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water'],
#  ['frankfurter', 'rolls/buns'],
#  ['chicken'],
#  ['butter', 'sugar', 'fruit/vegetable juice'],
#  ['butter milk'],
#  ['tropical fruit', 'cream cheese', 'processed cheese', 'detergent'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'frozen dessert',
#   'rolls/buns',
#   'flour',
#   'sweet spreads',
#   'salty snack',
#   'waffles',
#   'candy'],
#  ['bottled water'],
#  ['sausage', 'rolls/buns', 'soda'],
#  ['brown bread', 'soda', 'fruit/vegetable juice', 'canned beer', 'newspapers'],
#  ['yogurt', 'beverages', 'bottled water'],
#  ['hamburger meat',
#   'other vegetables',
#   'rolls/buns',
#   'spices',
#   'bottled water',
#   'hygiene articles'],
#  ['root vegetables', 'other vegetables', 'whole milk', 'beverages'],
#  ['pork',
#   'berries',
#   'other vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'artif. sweetener',
#   'soda'],
#  ['beef', 'grapes'],
#  ['pastry'],
#  ['root vegetables', 'other vegetables', 'whole milk'],
#  ['citrus fruit', 'zwieback'],
#  ['sausage', 'rolls/buns', 'soda', 'canned beer', 'specialty bar'],
#  ['tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'yogurt',
#   'domestic eggs',
#   'brown bread',
#   'pastry',
#   'sugar',
#   'cereals',
#   'coffee',
#   'soda',
#   'waffles'],
#  ['berries'],
#  ['butter milk',
#   'yogurt',
#   'cream cheese',
#   'spread cheese',
#   'rolls/buns',
#   'bottled water',
#   'soda'],
#  ['pastry'],
#  ['root vegetables',
#   'other vegetables',
#   'butter',
#   'curd',
#   'whipped/sour cream',
#   'UHT-milk',
#   'hard cheese',
#   'rolls/buns',
#   'bottled water'],
#  ['sausage', 'rolls/buns', 'cat food'],
#  ['ham', 'grapes', 'other vegetables'],
#  ['turkey',
#   'tropical fruit',
#   'other vegetables',
#   'curd',
#   'domestic eggs',
#   'brown bread',
#   'semi-finished bread',
#   'margarine',
#   'baking powder'],
#  ['whole milk', 'yogurt', 'processed cheese', 'pickled vegetables'],
#  ['whole milk', 'curd', 'yogurt'],
#  ['packaged fruit/vegetables', 'brown bread'],
#  ['rolls/buns',
#   'oil',
#   'bottled water',
#   'chewing gum',
#   'chocolate marshmallow',
#   'hygiene articles'],
#  ['ham', 'beef', 'whipped/sour cream', 'ice cream', 'rolls/buns'],
#  ['rolls/buns', 'pastry'],
#  ['other vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'canned fish',
#   'salty snack',
#   'seasonal products'],
#  ['sausage'],
#  ['sausage', 'beef'],
#  ['frankfurter', 'tropical fruit', 'rolls/buns', 'brown bread'],
#  ['rolls/buns', 'pastry'],
#  ['curd cheese'],
#  ['red/blush wine'],
#  ['sausage', 'whole milk'],
#  ['tropical fruit',
#   'pip fruit',
#   'berries',
#   'whole milk',
#   'frozen potato products',
#   'rolls/buns',
#   'pickled vegetables'],
#  ['whole milk',
#   'butter',
#   'margarine',
#   'specialty fat',
#   'specialty chocolate',
#   'candles'],
#  ['frankfurter',
#   'citrus fruit',
#   'whole milk',
#   'domestic eggs',
#   'oil',
#   'sparkling wine',
#   'specialty chocolate'],
#  ['whole milk', 'meat spreads'],
#  ['other vegetables', 'whole milk', 'rolls/buns'],
#  ['citrus fruit', 'whole milk', 'curd', 'butter milk'],
#  ['flour', 'salt', 'bottled water', 'fruit/vegetable juice'],
#  ['sugar', 'bottled water', 'soda'],
#  ['frozen meals'],
#  ['root vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'domestic eggs',
#   'rolls/buns',
#   'oil',
#   'margarine',
#   'canned vegetables',
#   'fruit/vegetable juice'],
#  ['root vegetables', 'onions', 'hard cheese'],
#  ['herbs', 'condensed milk', 'frozen vegetables', 'salt', 'oil', 'white wine'],
#  ['sausage', 'root vegetables', 'onions', 'yogurt', 'rolls/buns', 'brandy'],
#  ['coffee'],
#  ['pork', 'other vegetables'],
#  ['berries'],
#  ['fruit/vegetable juice', 'salty snack'],
#  ['citrus fruit', 'butter milk', 'yogurt'],
#  ['pork',
#   'hamburger meat',
#   'citrus fruit',
#   'berries',
#   'onions',
#   'whipped/sour cream',
#   'rice',
#   'coffee'],
#  ['grapes'],
#  ['sausage',
#   'sliced cheese',
#   'rolls/buns',
#   'brown bread',
#   'fruit/vegetable juice',
#   'canned beer',
#   'red/blush wine',
#   'waffles'],
#  ['chicken',
#   'hamburger meat',
#   'citrus fruit',
#   'tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'butter',
#   'pasta',
#   'oil'],
#  ['whole milk', 'yogurt'],
#  ['citrus fruit'],
#  ['soda'],
#  ['sausage',
#   'pork',
#   'grapes',
#   'whole milk',
#   'rolls/buns',
#   'pastry',
#   'soda',
#   'specialty bar'],
#  ['frankfurter', 'rolls/buns'],
#  ['sausage',
#   'whole milk',
#   'yogurt',
#   'coffee',
#   'fruit/vegetable juice',
#   'bottled beer',
#   'softener',
#   'napkins',
#   'photo/film'],
#  ['rolls/buns'],
#  ['beef', 'citrus fruit', 'berries', 'root vegetables', 'brown bread'],
#  ['whole milk',
#   'whipped/sour cream',
#   'rolls/buns',
#   'soda',
#   'waffles',
#   'candy'],
#  ['tropical fruit'],
#  ['frankfurter',
#   'sausage',
#   'root vegetables',
#   'other vegetables',
#   'rolls/buns',
#   'oil',
#   'pickled vegetables',
#   'bottled beer',
#   'chewing gum'],
#  ['packaged fruit/vegetables'],
#  ['whole milk',
#   'dessert',
#   'frozen vegetables',
#   'rolls/buns',
#   'margarine',
#   'bottled water',
#   'red/blush wine'],
#  ['berries'],
#  ['citrus fruit', 'berries', 'UHT-milk'],
#  ['tropical fruit', 'whole milk'],
#  ['hamburger meat',
#   'whole milk',
#   'frozen vegetables',
#   'rolls/buns',
#   'bottled beer'],
#  ['hamburger meat',
#   'other vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'domestic eggs',
#   'soda'],
#  ['whole milk', 'cream cheese'],
#  ['fish',
#   'other vegetables',
#   'pastry',
#   'margarine',
#   'coffee',
#   'long life bakery product',
#   'male cosmetics'],
#  ['frankfurter', 'sausage', 'long life bakery product'],
#  ['packaged fruit/vegetables', 'dessert', 'semi-finished bread'],
#  ['pastry'],
#  ['other vegetables'],
#  ['frankfurter',
#   'sausage',
#   'citrus fruit',
#   'tropical fruit',
#   'pip fruit',
#   'whole milk',
#   'hard cheese',
#   'cream cheese',
#   'domestic eggs',
#   'rice',
#   'sugar',
#   'canned fruit',
#   'misc. beverages',
#   'fruit/vegetable juice'],
#  ['sausage', 'butter milk'],
#  ['frankfurter'],
#  ['whole milk', 'yogurt', 'beverages', 'brown bread'],
#  ['berries'],
#  ['curd', 'flour'],
#  ['tropical fruit', 'other vegetables'],
#  ['rolls/buns'],
#  ['frankfurter', 'sausage', 'whole milk', 'rolls/buns'],
#  ['other vegetables', 'misc. beverages'],
#  ['whole milk'],
#  ['citrus fruit', 'butter', 'cream cheese', 'white bread', 'oil', 'margarine'],
#  ['frankfurter'],
#  ['frankfurter',
#   'ham',
#   'pip fruit',
#   'other vegetables',
#   'whole milk',
#   'soft cheese',
#   'frozen vegetables',
#   'rolls/buns',
#   'sugar'],
#  ['butter milk', 'yogurt', 'honey', 'soda'],
#  ['hamburger meat', 'citrus fruit', 'onions', 'rolls/buns', 'bottled water'],
#  ['pasta'],
#  ['other vegetables', 'whole milk', 'meat spreads', 'cake bar', 'chocolate'],
#  ['sausage', 'pork', 'citrus fruit', 'dessert', 'white bread', 'dishes'],
#  ['grapes', 'other vegetables', 'curd', 'dessert', 'yogurt'],
#  ['root vegetables',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'beverages',
#   'soft cheese',
#   'frozen vegetables',
#   'fruit/vegetable juice'],
#  ['coffee'],
#  ['whole milk', 'rolls/buns', 'sugar', 'bottled water'],
#  ['tropical fruit',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'whole milk'],
#  ['beef', 'herbs', 'flour', 'cling film/bags'],
#  ['whole milk', 'butter', 'dessert'],
#  ['frankfurter', 'soda'],
#  ['tropical fruit', 'specialty cheese'],
#  ['finished products', 'other vegetables', 'frozen vegetables'],
#  ['beverages'],
#  ['hamburger meat', 'root vegetables'],
#  ['whole milk', 'pastry'],
#  ['finished products', 'white wine'],
#  ['ham',
#   'tropical fruit',
#   'other vegetables',
#   'whole milk',
#   'white bread',
#   'brown bread',
#   'fruit/vegetable juice'],
#  ['curd', 'butter milk', 'cocoa drinks', 'salty snack'],
#  ['curd',
#   'dessert',
#   'soda',
#   'salty snack',
#   'waffles',
#   'cake bar',
#   'chocolate'],
#  ['whole milk', 'cream cheese', 'cereals'],
#  ['whole milk'],
#  ['dessert'],
#  ['sausage', 'soft cheese'],
#  ['other vegetables', 'bottled water', 'waffles', 'dishes'],
#  ['ham', 'whole milk'],
#  ['other vegetables'],
#  ['other vegetables'],
#  ['soda', 'bottled beer', 'white wine'],
#  ['herbs'],
#  ['frankfurter',
#   'ham',
#   'tropical fruit',
#   'pip fruit',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'soft cheese',
#   'sliced cheese',
#   'cream cheese',
#   'frozen meals',
#   'frozen fish',
#   'domestic eggs',
#   'white bread',
#   'sugar',
#   'cereals',
#   'fruit/vegetable juice',
#   'bottled beer'],
#  ['rolls/buns'],
#  ['curd',
#   'cream cheese',
#   'semi-finished bread',
#   'zwieback',
#   'cake bar',
#   'specialty bar'],
#  ['frankfurter', 'tropical fruit', 'whole milk', 'spread cheese', 'margarine'],
#  ['curd', 'salt', 'liquor (appetizer)', 'detergent'],
#  ['frankfurter'],
#  ['beef',
#   'berries',
#   'root vegetables',
#   'whole milk',
#   'dessert',
#   'spread cheese'],
#  ['pork', 'beef', 'pip fruit', 'herbs'],
#  ['frankfurter', 'citrus fruit', 'UHT-milk', 'margarine'],
#  ['sausage', 'bottled beer'],
#  ['curd'],
#  ['whole milk', 'bottled water'],
#  ['rolls/buns'],
#  ['pork', 'root vegetables', 'other vegetables', 'whole milk'],
#  ['citrus fruit'],
#  ['rolls/buns', 'pastry'],
#  ['butter', 'yogurt', 'bottled water', 'soda', 'make up remover'],
#  ['condensed milk', 'sugar', 'coffee'],
#  ['sausage', 'other vegetables', 'yogurt', 'soda'],
#  ['whole milk', 'beverages', 'UHT-milk'],
#  ['sausage', 'pork', 'beef', 'whole milk', 'rolls/buns'],
#  ['beverages'],
#  ['bottled water'],
#  ['cleaner'],
#  ['sausage', 'soda', 'newspapers'],
#  ['sausage',
#   'beef',
#   'citrus fruit',
#   'other vegetables',
#   'whole milk',
#   'butter milk',
#   'whipped/sour cream',
#   'beverages',
#   'hard cheese',
#   'rolls/buns',
#   'dish cleaner'],
#  ['misc. beverages'],
#  ['sausage', 'sliced cheese', 'rolls/buns', 'soda', 'canned beer'],
#  ['meat', 'curd', 'bottled beer'],
#  ['frankfurter',
#   'meat',
#   'tropical fruit',
#   'onions',
#   'oil',
#   'baking powder',
#   'tea'],
#  ['ice cream', 'rolls/buns'],
#  ['tropical fruit',
#   'berries',
#   'root vegetables',
#   'other vegetables',
#   'bottled water'],
#  ['meat',
#   'citrus fruit',
#   'other vegetables',
#   'curd',
#   'dessert',
#   'butter milk',
#   'beverages',
#   'cream cheese',
#   'rolls/buns',
#   'brown bread',
#   'tea'],
#  ['whole milk', 'mustard'],
#  ['sausage',
#   'beef',
#   'beverages',
#   'sliced cheese',
#   'rolls/buns',
#   'spices',
#   'house keeping products'],
#  ['frankfurter',
#   'sausage',
#   'root vegetables',
#   'butter',
#   'curd',
#   'sliced cheese',
#   'rolls/buns',
#   'salty snack'],
#  ['meat', 'other vegetables', 'butter'],
#  ['root vegetables',
#   'beverages',
#   'Instant food products',
#   'pickled vegetables'],
#  ['root vegetables',
#   'herbs',
#   'other vegetables',
#   'whole milk',
#   'sliced cheese'],
#  ['whole milk', 'whipped/sour cream', 'semi-finished bread'],
#  ['citrus fruit',
#   'whole milk',
#   'curd',
#   'dessert',
#   'yogurt',
#   'whipped/sour cream',
#   'frozen dessert',
#   'rolls/buns',
#   'salt',
#   'sugar',
#   'cereals',
#   'canned vegetables',
#   'canned fish',
#   'skin care',
#   'hygiene articles'],
#  ['citrus fruit', 'curd', 'pastry', 'margarine', 'sugar', 'candy'],
#  ['other vegetables',
#   'whole milk',
#   'bottled water',
#   'soda',
#   'misc. beverages',
#   'bottled beer',
#   'red/blush wine'],
#  ['citrus fruit', 'whole milk'],
#  ['sausage', 'oil', 'hygiene articles'],
#  ['frankfurter',
#   'beef',
#   'hamburger meat',
#   'grapes',
#   'root vegetables',
#   'whole milk',
#   'butter',
#   'frozen dessert',
#   'potato products',
#   'bottled water'],
#  ['hard cheese', 'rolls/buns', 'bottled water'],
#  ['cream cheese', 'rolls/buns', 'soda'],
#  ['turkey', 'beef', 'frozen vegetables', 'dishes'],
#  ['pork', 'other vegetables', 'whipped/sour cream', 'rolls/buns', 'soda'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['sausage',
#   'pip fruit',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'sliced cheese',
#   'rolls/buns',
#   'bottled water'],
#  ['pip fruit', 'other vegetables'],
#  ['root vegetables', 'other vegetables'],
#  ['sausage',
#   'citrus fruit',
#   'tropical fruit',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'bottled water',
#   'soda',
#   'chocolate'],
#  ['root vegetables', 'whole milk', 'pet care'],
#  ['pork', 'berries', 'root vegetables', 'other vegetables', 'pastry'],
#  ['pickled vegetables'],
#  ['frankfurter',
#   'sausage',
#   'butter',
#   'whipped/sour cream',
#   'rolls/buns',
#   'margarine'],
#  ['tropical fruit',
#   'pip fruit',
#   'onions',
#   'other vegetables',
#   'whole milk',
#   'domestic eggs',
#   'sugar',
#   'soups',
#   'tea',
#   'soda',
#   'hygiene articles'],
#  ['meat', 'citrus fruit', 'berries', 'root vegetables', 'whole milk'],
#  ['frankfurter', 'rolls/buns', 'bottled water', 'fruit/vegetable juice'],
#  ['tropical fruit', 'margarine'],
#  ['tropical fruit',
#   'root vegetables',
#   'herbs',
#   'whole milk',
#   'butter milk',
#   'whipped/sour cream',
#   'flour'],
#  ['citrus fruit',
#   'pip fruit',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'cream cheese',
#   'domestic eggs',
#   'brown bread',
#   'margarine',
#   'baking powder'],
#  ['hamburger meat',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'rolls/buns',
#   'pastry',
#   'semi-finished bread',
#   'margarine',
#   'bottled water'],
#  ['chicken',
#   'pip fruit',
#   'other vegetables',
#   'whole milk',
#   'dessert',
#   'yogurt',
#   'whipped/sour cream',
#   'rolls/buns',
#   'pasta',
#   'soda'],
#  ['chicken',
#   'citrus fruit',
#   'tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'frozen fish'],
#  ['frankfurter',
#   'citrus fruit',
#   'onions',
#   'other vegetables',
#   'whole milk',
#   'rolls/buns',
#   'sugar'],
#  ['turkey', 'pip fruit', 'salad dressing'],
#  ['packaged fruit/vegetables',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'domestic eggs',
#   'brown bread',
#   'mustard',
#   'pickled vegetables',
#   'bottled water'],
#  ['citrus fruit'],
#  ['sausage', 'whole milk', 'yogurt', 'rolls/buns', 'brown bread'],
#  ['whole milk', 'frozen meals', 'pastry', 'fruit/vegetable juice'],
#  ['citrus fruit', 'sugar'],
#  ['citrus fruit', 'other vegetables', 'rolls/buns', 'salty snack'],
#  ['chicken',
#   'other vegetables',
#   'whole milk',
#   'vinegar',
#   'oil',
#   'bottled water',
#   'canned beer',
#   'napkins'],
#  ['hamburger meat',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'whipped/sour cream',
#   'specialty cheese',
#   'flour'],
#  ['sausage', 'pork', 'other vegetables', 'dessert', 'yogurt', 'oil'],
#  ['beef', 'berries', 'root vegetables', 'whole milk', 'whipped/sour cream'],
#  ['citrus fruit', 'packaged fruit/vegetables', 'yogurt'],
#  ['UHT-milk'],
#  ['beef', 'citrus fruit', 'other vegetables'],
#  ['sausage'],
#  ['frankfurter',
#   'beef',
#   'root vegetables',
#   'curd',
#   'dessert',
#   'yogurt',
#   'soft cheese',
#   'rolls/buns',
#   'mustard',
#   'pickled vegetables',
#   'canned beer',
#   'hygiene articles'],
#  ['onions', 'soda', 'chewing gum', 'chocolate'],
#  ['tropical fruit',
#   'packaged fruit/vegetables',
#   'cream cheese',
#   'white bread'],
#  ['bottled water'],
#  ['beef', 'white bread', 'pastry', 'pasta'],
#  ['sausage',
#   'chicken',
#   'tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'yogurt',
#   'candy',
#   'abrasive cleaner'],
#  ['chicken', 'whole milk', 'spices', 'long life bakery product'],
#  ['pork', 'citrus fruit', 'brown bread', 'pastry', 'sugar'],
#  ['meat', 'hard cheese'],
#  ['other vegetables', 'yogurt', 'brown bread'],
#  ['bottled water'],
#  ['tropical fruit', 'soda'],
#  ['sausage', 'citrus fruit', 'yogurt', 'coffee', 'soda', 'canned beer'],
#  ['grapes'],
#  ['domestic eggs', 'brown bread'],
#  ['rolls/buns', 'canned fish'],
#  ['tropical fruit'],
#  ['frankfurter', 'other vegetables', 'yogurt', 'brown bread'],
#  ['berries',
#   'root vegetables',
#   'other vegetables',
#   'curd',
#   'butter milk',
#   'cream cheese',
#   'roll products',
#   'margarine',
#   'misc. beverages',
#   'specialty chocolate'],
#  ['margarine'],
#  ['tropical fruit', 'yogurt', 'rolls/buns', 'soda'],
#  ['ham',
#   'other vegetables',
#   'whipped/sour cream',
#   'hard cheese',
#   'rolls/buns',
#   'soda',
#   'misc. beverages',
#   'chocolate'],
#  ['hamburger meat', 'white bread'],
#  ['yogurt', 'mayonnaise', 'rolls/buns', 'soda'],
#  ['soda'],
#  ['sausage', 'meat', 'hamburger meat'],
#  ['citrus fruit',
#   'pip fruit',
#   'beverages',
#   'hard cheese',
#   'pet care',
#   'soda',
#   'fruit/vegetable juice'],
#  ['frankfurter',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'frozen potato products',
#   'zwieback',
#   'specialty bar'],
#  ['sausage', 'citrus fruit', 'whole milk'],
#  ['frankfurter'],
#  ['salt', 'salty snack'],
#  ['curd',
#   'beverages',
#   'cream cheese',
#   'rolls/buns',
#   'pastry',
#   'soda',
#   'cake bar'],
#  ['other vegetables', 'butter'],
#  ['frankfurter', 'whole milk'],
#  ['root vegetables', 'whole milk', 'butter', 'processed cheese', 'mayonnaise'],
#  ['tropical fruit', 'whole milk', 'frozen meals'],
#  ['beef', 'hamburger meat'],
#  ['berries', 'whipped/sour cream', 'cereals', 'waffles'],
#  ['whipped/sour cream', 'canned beer'],
#  ['root vegetables', 'domestic eggs', 'margarine', 'chocolate marshmallow'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['whole milk'],
#  ['citrus fruit', 'whole milk', 'curd'],
#  ['pastry'],
#  ['frankfurter',
#   'sausage',
#   'pork',
#   'pip fruit',
#   'butter',
#   'processed cheese',
#   'white bread'],
#  ['tropical fruit', 'root vegetables', 'whole milk', 'whipped/sour cream'],
#  ['frankfurter',
#   'sausage',
#   'root vegetables',
#   'yogurt',
#   'whipped/sour cream',
#   'pastry'],
#  ['berries',
#   'root vegetables',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'curd',
#   'curd cheese',
#   'cat food',
#   'specialty bar'],
#  ['rolls/buns', 'brown bread', 'pastry', 'coffee'],
#  ['root vegetables',
#   'packaged fruit/vegetables',
#   'curd',
#   'dessert',
#   'frozen vegetables',
#   'specialty fat'],
#  ['other vegetables'],
#  ['berries'],
#  ['berries'],
#  ['other vegetables', 'butter milk', 'frozen meals'],
#  ['rolls/buns'],
#  ['ham',
#   'citrus fruit',
#   'whole milk',
#   'whipped/sour cream',
#   'rolls/buns',
#   'pastry',
#   'waffles'],
#  ['whole milk', 'frozen dessert', 'salty snack'],
#  ['tropical fruit', 'butter milk', 'rolls/buns'],
#  ['butter milk'],
#  ['bottled beer'],
#  ['onions',
#   'butter',
#   'whipped/sour cream',
#   'hard cheese',
#   'frozen vegetables',
#   'pasta',
#   'specialty fat',
#   'syrup',
#   'candy',
#   'napkins'],
#  ['hamburger meat',
#   'hard cheese',
#   'frozen meals',
#   'pasta',
#   'dog food',
#   'salty snack'],
#  ['sausage',
#   'liver loaf',
#   'other vegetables',
#   'cream cheese',
#   'pastry',
#   'soap'],
#  ['hard cheese', 'pastry'],
#  ['sausage', 'tropical fruit', 'condensed milk'],
#  ['onions', 'whole milk', 'beverages'],
#  ['yogurt', 'rolls/buns', 'pastry', 'bottled water', 'soda'],
#  ['sausage', 'whole milk'],
#  ['yogurt'],
#  ['domestic eggs', 'rolls/buns', 'dish cleaner'],
#  ['meat', 'other vegetables', 'whole milk'],
#  ['dish cleaner', 'bathroom cleaner', 'hygiene articles'],
#  ['other vegetables'],
#  ['whole milk',
#   'butter milk',
#   'yogurt',
#   'sliced cheese',
#   'rolls/buns',
#   'sweet spreads',
#   'coffee',
#   'fruit/vegetable juice',
#   'long life bakery product'],
#  ['other vegetables', 'whole milk', 'rolls/buns'],
#  ['tropical fruit'],
#  ['baking powder', 'bottled water', 'salty snack'],
#  ['frankfurter'],
#  ['other vegetables',
#   'whole milk',
#   'rolls/buns',
#   'margarine',
#   'bottled water'],
#  ['citrus fruit', 'tropical fruit', 'onions', 'other vegetables'],
#  ['sausage', 'ham', 'hamburger meat', 'whole milk', 'soda', 'softener'],
#  ['domestic eggs', 'rolls/buns', 'specialty bar'],
#  ['pork',
#   'citrus fruit',
#   'tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'curd'],
#  ['specialty cheese',
#   'frozen vegetables',
#   'coffee',
#   'soda',
#   'fruit/vegetable juice'],
#  ['pork', 'citrus fruit', 'pip fruit', 'yogurt', 'fruit/vegetable juice'],
#  ['beef', 'berries', 'whipped/sour cream', 'domestic eggs'],
#  ['other vegetables'],
#  ['chicken', 'yogurt', 'sliced cheese', 'rolls/buns', 'chewing gum'],
#  ['soda'],
#  ['root vegetables', 'pastry', 'bottled water'],
#  ['berries', 'pet care', 'cake bar'],
#  ['citrus fruit',
#   'tropical fruit',
#   'root vegetables',
#   'yogurt',
#   'canned vegetables',
#   'bottled water',
#   'soda'],
#  ['whole milk', 'oil', 'canned fruit'],
#  ['soda'],
#  ['bottled water'],
#  ['tropical fruit', 'other vegetables'],
#  ['bottled water'],
#  ['citrus fruit', 'UHT-milk', 'cream cheese'],
#  ['bottled water', 'canned beer'],
#  ['onions', 'other vegetables', 'pastry', 'bottled water', 'soda'],
#  ['dessert', 'oil', 'cat food'],
#  ['beef',
#   'other vegetables',
#   'whole milk',
#   'frozen potato products',
#   'rolls/buns',
#   'oil',
#   'margarine',
#   'coffee',
#   'dental care',
#   'hygiene articles'],
#  ['rolls/buns',
#   'zwieback',
#   'bottled water',
#   'misc. beverages',
#   'bottled beer',
#   'canned beer'],
#  ['beef',
#   'tropical fruit',
#   'root vegetables',
#   'onions',
#   'other vegetables',
#   'instant coffee'],
#  ['coffee'],
#  ['rolls/buns', 'brown bread'],
#  ['pork',
#   'beef',
#   'hamburger meat',
#   'other vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'rolls/buns',
#   'margarine'],
#  ['soda', 'canned beer', 'liquor (appetizer)', 'hygiene articles', 'napkins'],
#  ['sausage', 'ham', 'other vegetables', 'ice cream'],
#  ['beef', 'root vegetables', 'other vegetables', 'rolls/buns'],
#  ['whole milk', 'butter', 'bottled water'],
#  ['pork', 'ice cream', 'hygiene articles'],
#  ['berries',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'ice cream',
#   'fruit/vegetable juice',
#   'salty snack'],
#  ['sausage',
#   'other vegetables',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'frozen vegetables',
#   'rolls/buns'],
#  ['bottled water', 'misc. beverages'],
#  ['tropical fruit',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'hard cheese',
#   'frozen dessert',
#   'rice'],
#  ['herbs'],
#  ['yogurt'],
#  ['bottled beer'],
#  ['beef'],
#  ['whole milk', 'honey'],
#  ['frankfurter', 'rolls/buns', 'pastry', 'snack products'],
#  ['frankfurter',
#   'sausage',
#   'liver loaf',
#   'root vegetables',
#   'curd',
#   'frozen vegetables',
#   'rolls/buns',
#   'semi-finished bread',
#   'hygiene articles'],
#  ['other vegetables', 'whole milk'],
#  ['frankfurter', 'root vegetables', 'pickled vegetables', 'soda'],
#  ['whole milk', 'rolls/buns'],
#  ['frankfurter', 'margarine'],
#  ['other vegetables'],
#  ['bottled water'],
#  ['pork', 'onions', 'whole milk', 'butter', 'rolls/buns', 'pastry', 'rum'],
#  ['other vegetables', 'whipped/sour cream', 'specialty cheese'],
#  ['hamburger meat', 'whole milk', 'curd', 'pasta'],
#  ['hamburger meat', 'citrus fruit'],
#  ['whole milk', 'cream cheese', 'soda'],
#  ['pastry'],
#  ['ham',
#   'pip fruit',
#   'whole milk',
#   'curd',
#   'dessert',
#   'butter milk',
#   'whipped/sour cream',
#   'sliced cheese',
#   'cream cheese',
#   'white bread',
#   'coffee',
#   'long life bakery product',
#   'chocolate'],
#  ['frankfurter'],
#  ['sausage',
#   'turkey',
#   'beef',
#   'root vegetables',
#   'domestic eggs',
#   'rolls/buns',
#   'flour',
#   'rice',
#   'organic products',
#   'misc. beverages'],
#  ['bottled water', 'bottled beer'],
#  ['meat', 'other vegetables', 'hard cheese', 'frozen meals', 'bottled water'],
#  ['dessert'],
#  ['other vegetables', 'packaged fruit/vegetables', 'UHT-milk'],
#  ['beverages', 'rolls/buns'],
#  ['ham', 'mustard'],
#  ['brown bread', 'soda', 'salty snack'],
#  ['whole milk', 'cream cheese'],
#  ['rolls/buns', 'pastry'],
#  ['bottled beer'],
#  ['pet care'],
#  ['citrus fruit', 'other vegetables'],
#  ['pork', 'other vegetables', 'frozen vegetables'],
#  ['other vegetables'],
#  ['white wine'],
#  ['whole milk', 'dessert'],
#  ['pip fruit', 'white wine'],
#  ['sugar', 'soda'],
#  ['tropical fruit',
#   'pip fruit',
#   'rolls/buns',
#   'coffee',
#   'fruit/vegetable juice'],
#  ['root vegetables',
#   'cream cheese',
#   'spread cheese',
#   'frozen dessert',
#   'white bread',
#   'bottled water',
#   'soda',
#   'misc. beverages',
#   'fruit/vegetable juice'],
#  ['soda'],
#  ['whole milk'],
#  ['tropical fruit', 'other vegetables', 'yogurt', 'bottled water'],
#  ['white bread'],
#  ['brown bread', 'sugar'],
#  ['tropical fruit',
#   'root vegetables',
#   'coffee',
#   'bottled water',
#   'red/blush wine',
#   'candy',
#   'house keeping products'],
#  ['coffee', 'detergent', 'hygiene articles'],
#  ['pork',
#   'beef',
#   'berries',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'mayonnaise',
#   'frozen fish',
#   'frozen potato products',
#   'oil',
#   'mustard',
#   'cat food',
#   'coffee',
#   'soda',
#   'chocolate',
#   'dish cleaner',
#   'napkins'],
#  ['other vegetables'],
#  ['yogurt', 'bottled water'],
#  ['bottled water'],
#  ['citrus fruit',
#   'berries',
#   'other vegetables',
#   'butter milk',
#   'sugar',
#   'fruit/vegetable juice'],
#  ['hamburger meat', 'root vegetables', 'other vegetables', 'whole milk'],
#  ['packaged fruit/vegetables'],
#  ['other vegetables'],
#  ['whole milk',
#   'yogurt',
#   'frozen potato products',
#   'margarine',
#   'bottled water',
#   'fruit/vegetable juice'],
#  ['herbs'],
#  ['citrus fruit', 'spread cheese', 'rolls/buns'],
#  ['tropical fruit', 'whole milk', 'beverages', 'white bread', 'pasta'],
#  ['soda'],
#  ['white bread', 'bottled water', 'soda'],
#  ['coffee', 'chewing gum'],
#  ['tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'honey',
#   'baking powder',
#   'coffee',
#   'red/blush wine'],
#  ['pork', 'pip fruit', 'whole milk'],
#  ['citrus fruit'],
#  ['frankfurter'],
#  ['frankfurter',
#   'tropical fruit',
#   'pip fruit',
#   'curd',
#   'UHT-milk',
#   'hard cheese',
#   'domestic eggs',
#   'rolls/buns',
#   'hygiene articles',
#   'napkins'],
#  ['yogurt', 'fruit/vegetable juice'],
#  ['sausage',
#   'whole milk',
#   'yogurt',
#   'brown bread',
#   'cereals',
#   'bottled water'],
#  ['pip fruit', 'whole milk', 'curd', 'pastry'],
#  ['root vegetables'],
#  ['onions'],
#  ['hamburger meat'],
#  ['rolls/buns', 'soda', 'snack products'],
#  ['other vegetables',
#   'curd',
#   'frozen meals',
#   'frozen potato products',
#   'soda',
#   'bottled beer',
#   'kitchen towels'],
#  ['curd', 'whipped/sour cream', 'rolls/buns', 'zwieback'],
#  ['butter', 'fruit/vegetable juice'],
#  ['other vegetables',
#   'whole milk',
#   'yogurt',
#   'domestic eggs',
#   'bottled water'],
#  ['beef',
#   'tropical fruit',
#   'herbs',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'whipped/sour cream'],
#  ['sausage'],
#  ['fruit/vegetable juice'],
#  ['rolls/buns', 'coffee', 'long life bakery product', 'detergent'],
#  ['pip fruit', 'whole milk', 'bottled water'],
#  ['frozen vegetables',
#   'bottled beer',
#   'liquor (appetizer)',
#   'chewing gum',
#   'napkins'],
#  ['hamburger meat',
#   'root vegetables',
#   'other vegetables',
#   'domestic eggs',
#   'roll products',
#   'oil',
#   'margarine'],
#  ['root vegetables',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'fruit/vegetable juice'],
#  ['frozen vegetables'],
#  ['hamburger meat', 'UHT-milk'],
#  ['pip fruit', 'whole milk', 'curd'],
#  ['grapes', 'root vegetables', 'frozen vegetables', 'domestic eggs'],
#  ['root vegetables',
#   'packaged fruit/vegetables',
#   'butter',
#   'whipped/sour cream'],
#  ['citrus fruit', 'frozen vegetables', 'rolls/buns', 'canned beer'],
#  ['cling film/bags'],
#  ['frankfurter', 'whole milk', 'rolls/buns', 'margarine', 'baking powder'],
#  ['whole milk'],
#  ['pork',
#   'tropical fruit',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'hard cheese',
#   'frozen meals',
#   'frozen dessert',
#   'domestic eggs',
#   'cereals',
#   'baking powder',
#   'fruit/vegetable juice'],
#  ['chicken'],
#  ['sausage', 'dish cleaner'],
#  ['whipped/sour cream', 'pastry'],
#  ['root vegetables'],
#  ['rolls/buns'],
#  ['other vegetables', 'bottled beer'],
#  ['citrus fruit',
#   'tropical fruit',
#   'berries',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'bottled water',
#   'rubbing alcohol',
#   'hygiene articles'],
#  ['whole milk', 'processed cheese', 'brown bread', 'pastry'],
#  ['frankfurter',
#   'sausage',
#   'tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'pastry'],
#  ['coffee'],
#  ['ham', 'rolls/buns'],
#  ['pip fruit', 'whole milk'],
#  ['pork',
#   'pip fruit',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'white bread',
#   'sugar',
#   'bottled water'],
#  ['pip fruit', 'butter', 'frozen meals', 'pasta'],
#  ['beef', 'hamburger meat', 'citrus fruit', 'whole milk', 'mustard'],
#  ['sausage',
#   'meat',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'soda',
#   'bottled beer',
#   'chocolate'],
#  ['tropical fruit',
#   'curd',
#   'yogurt',
#   'rolls/buns',
#   'brown bread',
#   'bottled water',
#   'bottled beer'],
#  ['beef',
#   'citrus fruit',
#   'curd',
#   'rolls/buns',
#   'oil',
#   'margarine',
#   'specialty bar',
#   'detergent'],
#  ['meat',
#   'pork',
#   'beef',
#   'citrus fruit',
#   'root vegetables',
#   'other vegetables',
#   'whole milk'],
#  ['meat',
#   'hamburger meat',
#   'root vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'butter'],
#  ['bottled water', 'soda', 'red/blush wine', 'long life bakery product'],
#  ['pastry'],
#  ['pork', 'whole milk', 'pastry'],
#  ['pip fruit', 'sliced cheese', 'pastry', 'white wine', 'light bulbs'],
#  ['beef',
#   'citrus fruit',
#   'tropical fruit',
#   'yogurt',
#   'UHT-milk',
#   'frozen vegetables',
#   'rolls/buns',
#   'bottled water'],
#  ['beef', 'citrus fruit', 'berries', 'brown bread', 'sugar', 'coffee'],
#  ['rolls/buns'],
#  ['citrus fruit',
#   'tropical fruit',
#   'herbs',
#   'whole milk',
#   'butter',
#   'curd',
#   'whipped/sour cream',
#   'frozen vegetables',
#   'canned vegetables'],
#  ['meat',
#   'beef',
#   'herbs',
#   'whole milk',
#   'frozen dessert',
#   'rolls/buns',
#   'semi-finished bread',
#   'flour',
#   'oil',
#   'coffee'],
#  ['beverages', 'pastry'],
#  ['beef', 'citrus fruit', 'other vegetables'],
#  ['ham', 'whole milk', 'white bread', 'margarine'],
#  ['hamburger meat',
#   'whole milk',
#   'oil',
#   'ketchup',
#   'soups',
#   'Instant food products',
#   'canned fish',
#   'coffee',
#   'bottled beer',
#   'hygiene articles'],
#  ['beef',
#   'citrus fruit',
#   'other vegetables',
#   'butter milk',
#   'sliced cheese',
#   'processed cheese',
#   'rolls/buns',
#   'margarine',
#   'bottled water'],
#  ['beef',
#   'citrus fruit',
#   'whole milk',
#   'domestic eggs',
#   'rolls/buns',
#   'pastry',
#   'roll products',
#   'tea'],
#  ['root vegetables', 'whole milk'],
#  ['citrus fruit',
#   'tropical fruit',
#   'grapes',
#   'other vegetables',
#   'frozen vegetables',
#   'pickled vegetables',
#   'fruit/vegetable juice',
#   'liquor',
#   'rum',
#   'liquor (appetizer)',
#   'candy'],
#  ['yogurt'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'whipped/sour cream',
#   'brown bread',
#   'canned fish'],
#  ['frankfurter', 'root vegetables'],
#  ['beef',
#   'other vegetables',
#   'whole milk',
#   'brown bread',
#   'pastry',
#   'salty snack',
#   'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'rolls/buns',
#   'meat spreads',
#   'bottled water',
#   'soda',
#   'misc. beverages',
#   'waffles',
#   'chocolate'],
#  ['hamburger meat', 'other vegetables', 'yogurt', 'rolls/buns'],
#  ['hamburger meat',
#   'citrus fruit',
#   'root vegetables',
#   'rolls/buns',
#   'Instant food products',
#   'canned fish',
#   'bottled water',
#   'soda',
#   'fruit/vegetable juice'],
#  ['frankfurter', 'sausage', 'domestic eggs', 'soda', 'chewing gum'],
#  ['tropical fruit', 'domestic eggs', 'rolls/buns'],
#  ['frankfurter',
#   'root vegetables',
#   'onions',
#   'other vegetables',
#   'white bread'],
#  ['chicken',
#   'hamburger meat',
#   'herbs',
#   'whipped/sour cream',
#   'soups',
#   'soda',
#   'canned beer',
#   'dish cleaner',
#   'napkins'],
#  ['coffee'],
#  ['tropical fruit'],
#  ['meat'],
#  ['cream cheese', 'bottled water'],
#  ['rolls/buns', 'pastry'],
#  ['citrus fruit',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'potato products',
#   'fruit/vegetable juice'],
#  ['whole milk', 'rolls/buns'],
#  ['frankfurter',
#   'citrus fruit',
#   'butter milk',
#   'UHT-milk',
#   'rolls/buns',
#   'female sanitary products'],
#  ['ham', 'other vegetables', 'butter', 'whipped/sour cream', 'sugar'],
#  ['frankfurter', 'citrus fruit', 'bottled beer'],
#  ['sausage', 'onions', 'curd', 'yogurt', 'domestic eggs'],
#  ['whole milk', 'domestic eggs', 'rolls/buns'],
#  ['rolls/buns', 'bottled beer'],
#  ['whole milk', 'hard cheese'],
#  ['sausage', 'root vegetables', 'other vegetables', 'rolls/buns'],
#  ['curd', 'butter milk', 'yogurt'],
#  ['frankfurter',
#   'hamburger meat',
#   'whole milk',
#   'rolls/buns',
#   'potato products',
#   'mustard',
#   'coffee',
#   'waffles',
#   'chocolate marshmallow',
#   'soap'],
#  ['chicken', 'butter'],
#  ['sausage',
#   'meat',
#   'tropical fruit',
#   'pip fruit',
#   'pastry',
#   'sugar',
#   'coffee',
#   'candles'],
#  ['pork', 'whole milk', 'whipped/sour cream'],
#  ['yogurt', 'pastry'],
#  ['whole milk',
#   'sliced cheese',
#   'margarine',
#   'cat food',
#   'detergent',
#   'dishes'],
#  ['frankfurter',
#   'ham',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'pastry',
#   'vinegar',
#   'sugar',
#   'soda',
#   'fruit/vegetable juice'],
#  ['beef', 'whole milk', 'brown bread', 'specialty chocolate'],
#  ['pip fruit', 'other vegetables', 'butter milk', 'cream cheese'],
#  ['sausage', 'whole milk', 'rolls/buns', 'coffee'],
#  ['pastry'],
#  ['chicken', 'beef'],
#  ['root vegetables',
#   'other vegetables',
#   'whole milk',
#   'sliced cheese',
#   'frozen vegetables',
#   'frozen fish',
#   'frozen dessert'],
#  ['whole milk', 'frozen meals'],
#  ['rolls/buns'],
#  ['yogurt', 'salt', 'jam', 'sparkling wine'],
#  ['tropical fruit', 'curd', 'sliced cheese', 'rolls/buns'],
#  ['curd', 'UHT-milk', 'artif. sweetener'],
#  ['beef', 'berries', 'onions'],
#  ['whole milk',
#   'brown bread',
#   'pasta',
#   'margarine',
#   'bottled water',
#   'napkins'],
#  ['pork', 'UHT-milk', 'bottled water', 'soda'],
#  ['other vegetables', 'curd', 'yogurt', 'curd cheese', 'margarine', 'cleaner'],
#  ['rolls/buns',
#   'soda',
#   'fruit/vegetable juice',
#   'canned beer',
#   'white wine',
#   'long life bakery product'],
#  ['frankfurter', 'pip fruit', 'whole milk', 'rolls/buns'],
#  ['yogurt', 'hygiene articles', 'newspapers'],
#  ['whole milk', 'curd', 'sliced cheese', 'cat food'],
#  ['bottled water'],
#  ['frankfurter', 'beef'],
#  ['rolls/buns', 'soda', 'snack products'],
#  ['whole milk', 'pastry', 'bottled water'],
#  ['chicken',
#   'onions',
#   'other vegetables',
#   'whole milk',
#   'brown bread',
#   'white wine'],
#  ['tropical fruit', 'onions', 'whole milk', 'butter'],
#  ['sausage',
#   'turkey',
#   'other vegetables',
#   'yogurt',
#   'brown bread',
#   'oil',
#   'hygiene articles'],
#  ['sausage',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'hard cheese',
#   'soda',
#   'candy'],
#  ['frankfurter',
#   'citrus fruit',
#   'pastry',
#   'margarine',
#   'ready soups',
#   'instant coffee'],
#  ['UHT-milk', 'frozen dessert', 'fruit/vegetable juice', 'decalcifier'],
#  ['rolls/buns'],
#  ['yogurt'],
#  ['whipped/sour cream'],
#  ['rolls/buns'],
#  ['beverages'],
#  ['rolls/buns'],
#  ['citrus fruit', 'curd', 'yogurt', 'sliced cheese', 'rolls/buns', 'oil'],
#  ['bottled water'],
#  ['domestic eggs', 'rolls/buns', 'pastry', 'coffee'],
#  ['beef', 'pip fruit', 'root vegetables', 'rolls/buns'],
#  ['spread cheese', 'rolls/buns', 'bottled water'],
#  ['tropical fruit', 'spread cheese', 'rolls/buns'],
#  ['packaged fruit/vegetables', 'canned beer'],
#  ['whole milk', 'yogurt', 'bottled beer', 'white wine', 'salty snack'],
#  ['meat', 'beef', 'other vegetables', 'whole milk', 'butter', 'domestic eggs'],
#  ['onions', 'whole milk', 'bottled beer', 'liquor (appetizer)', 'detergent'],
#  ['frankfurter',
#   'grapes',
#   'other vegetables',
#   'butter milk',
#   'UHT-milk',
#   'brown bread',
#   'margarine',
#   'organic products',
#   'bottled water'],
#  ['beef', 'rolls/buns'],
#  ['sausage', 'bottled beer'],
#  ['chicken', 'onions', 'herbs'],
#  ['sausage',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'bottled beer'],
#  ['tropical fruit', 'whole milk', 'curd', 'yogurt'],
#  ['frankfurter', 'rolls/buns', 'soda', 'abrasive cleaner', 'newspapers'],
#  ['sausage', 'tropical fruit'],
#  ['beef', 'tropical fruit', 'root vegetables'],
#  ['tropical fruit', 'pastry', 'flour'],
#  ['frankfurter', 'rolls/buns'],
#  ['grapes'],
#  ['beverages'],
#  ['curd', 'bottled beer'],
#  ['ice cream', 'sugar'],
#  ['sausage', 'rolls/buns', 'soda', 'canned beer'],
#  ['dessert', 'beverages'],
#  ['berries', 'other vegetables', 'whole milk'],
#  ['pork',
#   'tropical fruit',
#   'rolls/buns',
#   'semi-finished bread',
#   'bottled beer'],
#  ['frankfurter',
#   'chicken',
#   'pork',
#   'citrus fruit',
#   'other vegetables',
#   'whole milk',
#   'butter milk',
#   'whipped/sour cream',
#   'cream cheese',
#   'frozen dessert',
#   'domestic eggs',
#   'rolls/buns',
#   'sugar'],
#  ['pork',
#   'beef',
#   'whole milk',
#   'domestic eggs',
#   'bottled water',
#   'bottled beer'],
#  ['frankfurter',
#   'pork',
#   'citrus fruit',
#   'root vegetables',
#   'onions',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'cat food'],
#  ['frozen dessert'],
#  ['chicken',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'condensed milk',
#   'frozen vegetables'],
#  ['vinegar'],
#  ['rolls/buns', 'soda'],
#  ['pork', 'root vegetables', 'whole milk'],
#  ['rolls/buns'],
#  ['grapes', 'other vegetables', 'zwieback', 'Instant food products'],
#  ['frankfurter',
#   'citrus fruit',
#   'whipped/sour cream',
#   'cream cheese',
#   'rolls/buns',
#   'baking powder',
#   'seasonal products'],
#  ['finished products',
#   'root vegetables',
#   'packaged fruit/vegetables',
#   'yogurt',
#   'specialty cheese',
#   'frozen vegetables',
#   'ice cream',
#   'soda'],
#  ['onions', 'other vegetables'],
#  ['tropical fruit', 'whole milk'],
#  ['other vegetables', 'cream cheese', 'tea', 'chocolate'],
#  ['ham', 'turkey', 'beef', 'other vegetables', 'whole milk'],
#  ['other vegetables', 'whole milk', 'margarine'],
#  ['sausage', 'beef'],
#  ['canned beer', 'liquor (appetizer)'],
#  ['ham',
#   'chicken',
#   'citrus fruit',
#   'berries',
#   'onions',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'frozen vegetables',
#   'rolls/buns',
#   'margarine',
#   'soda',
#   'liquor (appetizer)',
#   'cake bar',
#   'candy',
#   'seasonal products'],
#  ['packaged fruit/vegetables',
#   'whole milk',
#   'dessert',
#   'yogurt',
#   'UHT-milk',
#   'margarine',
#   'bottled water'],
#  ['meat', 'rolls/buns', 'soda'],
#  ['whole milk'],
#  ['chicken', 'UHT-milk', 'rolls/buns', 'coffee', 'long life bakery product'],
#  ['rolls/buns', 'red/blush wine'],
#  ['pet care'],
#  ['root vegetables', 'other vegetables', 'soda'],
#  ['frankfurter',
#   'hamburger meat',
#   'whole milk',
#   'domestic eggs',
#   'rolls/buns',
#   'brown bread',
#   'margarine',
#   'bottled water'],
#  ['chicken', 'grapes', 'whole milk', 'whipped/sour cream'],
#  ['frozen dessert'],
#  ['citrus fruit',
#   'tropical fruit',
#   'grapes',
#   'yogurt',
#   'rolls/buns',
#   'margarine',
#   'canned fruit',
#   'bottled water',
#   'soda',
#   'misc. beverages',
#   'candy',
#   'female sanitary products'],
#  ['sausage',
#   'pork',
#   'beef',
#   'berries',
#   'root vegetables',
#   'whole milk',
#   'butter',
#   'rolls/buns',
#   'cat food',
#   'bottled water'],
#  ['root vegetables',
#   'onions',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'frozen vegetables',
#   'rolls/buns',
#   'pasta',
#   'soups',
#   'baking powder',
#   'soda'],
#  ['root vegetables', 'whole milk', 'yogurt'],
#  ['frankfurter'],
#  ['root vegetables', 'whole milk', 'butter'],
#  ['berries',
#   'other vegetables',
#   'whipped/sour cream',
#   'UHT-milk',
#   'bottled water',
#   'soda',
#   'hygiene articles'],
#  ['tropical fruit',
#   'whole milk',
#   'rolls/buns',
#   'semi-finished bread',
#   'margarine',
#   'fruit/vegetable juice',
#   'long life bakery product'],
#  ['frankfurter', 'pork', 'beverages', 'frozen meals'],
#  ['frankfurter', 'sausage', 'frozen fish', 'margarine'],
#  ['soda'],
#  ['beef', 'whole milk', 'frozen vegetables', 'brown bread', 'pastry'],
#  ['whole milk', 'pastry', 'bottled water', 'newspapers'],
#  ['pork',
#   'fish',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'flour'],
#  ['whole milk'],
#  ['pork', 'grapes', 'UHT-milk', 'brown bread'],
#  ['root vegetables'],
#  ['citrus fruit',
#   'root vegetables',
#   'whole milk',
#   'butter',
#   'whipped/sour cream',
#   'oil',
#   'mustard',
#   'bottled water'],
#  ['pip fruit',
#   'herbs',
#   'other vegetables',
#   'whole milk',
#   'coffee',
#   'female sanitary products',
#   'hygiene articles'],
#  ['root vegetables', 'dessert', 'yogurt', 'cream cheese'],
#  ['tropical fruit', 'curd', 'rolls/buns', 'organic products'],
#  ['beef',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'soft cheese',
#   'hard cheese',
#   'domestic eggs',
#   'pasta',
#   'coffee'],
#  ['chicken', 'pork', 'whole milk', 'butter'],
#  ['citrus fruit',
#   'grapes',
#   'whole milk',
#   'rolls/buns',
#   'pastry',
#   'oil',
#   'margarine',
#   'candles'],
#  ['meat',
#   'beef',
#   'tropical fruit',
#   'pip fruit',
#   'other vegetables',
#   'whipped/sour cream',
#   'soft cheese',
#   'frozen meals',
#   'margarine',
#   'coffee',
#   'fruit/vegetable juice'],
#  ['cream cheese', 'spread cheese'],
#  ['citrus fruit', 'herbs', 'whole milk', 'bottled water', 'bottled beer'],
#  ['meat',
#   'other vegetables',
#   'whole milk',
#   'beverages',
#   'rolls/buns',
#   'margarine',
#   'chocolate',
#   'napkins'],
#  ['citrus fruit', 'tropical fruit'],
#  ['frankfurter',
#   'beef',
#   'tropical fruit',
#   'root vegetables',
#   'packaged fruit/vegetables',
#   'whole milk'],
#  ['citrus fruit'],
#  ['turkey', 'root vegetables', 'other vegetables', 'curd', 'bottled beer'],
#  ['citrus fruit',
#   'onions',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'rolls/buns',
#   'pasta',
#   'mustard',
#   'dog food'],
#  ['sausage'],
#  ['whole milk'],
#  ['berries', 'whole milk', 'whipped/sour cream'],
#  ['packaged fruit/vegetables', 'whole milk', 'rolls/buns'],
#  ['frankfurter'],
#  ['nuts/prunes',
#   'whole milk',
#   'semi-finished bread',
#   'jam',
#   'soda',
#   'potted plants'],
#  ['citrus fruit',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'butter',
#   'whipped/sour cream',
#   'flour',
#   'sugar',
#   'coffee',
#   'soda',
#   'sparkling wine'],
#  ['beef',
#   'citrus fruit',
#   'root vegetables',
#   'onions',
#   'curd',
#   'hard cheese',
#   'rolls/buns'],
#  ['whole milk', 'yogurt', 'frozen vegetables', 'coffee', 'canned beer'],
#  ['other vegetables'],
#  ['beef'],
#  ['fish',
#   'berries',
#   'other vegetables',
#   'whole milk',
#   'dessert',
#   'yogurt',
#   'spread cheese',
#   'coffee',
#   'white wine'],
#  ['other vegetables',
#   'whole milk',
#   'curd',
#   'frozen vegetables',
#   'domestic eggs',
#   'sugar',
#   'instant coffee'],
#  ['tropical fruit',
#   'berries',
#   'root vegetables',
#   'whole milk',
#   'butter',
#   'yogurt',
#   'whipped/sour cream',
#   'sliced cheese',
#   'hard cheese',
#   'specialty chocolate'],
#  ['sausage',
#   'pork',
#   'other vegetables',
#   'frozen fish',
#   'rolls/buns',
#   'semi-finished bread',
#   'artif. sweetener',
#   'ready soups',
#   'bottled water',
#   'hygiene articles'],
#  ['meat',
#   'root vegetables',
#   'whipped/sour cream',
#   'beverages',
#   'cream cheese',
#   'waffles'],
#  ['chicken',
#   'tropical fruit',
#   'pip fruit',
#   'root vegetables',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'butter',
#   'rolls/buns',
#   'margarine',
#   'sugar',
#   'rum',
#   'long life bakery product'],
#  ['berries',
#   'whole milk',
#   'whipped/sour cream',
#   'margarine',
#   'organic products',
#   'fruit/vegetable juice'],
#  ['frozen meals'],
#  ['beef', 'root vegetables', 'bottled beer', 'chocolate'],
#  ['chicken',
#   'pork',
#   'other vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'UHT-milk',
#   'domestic eggs',
#   'rolls/buns',
#   'bottled water',
#   'soda',
#   'fruit/vegetable juice'],
#  ['chicken',
#   'pork',
#   'hamburger meat',
#   'pip fruit',
#   'nuts/prunes',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'spread cheese',
#   'frozen potato products',
#   'brown bread',
#   'Instant food products',
#   'soda',
#   'fruit/vegetable juice'],
#  ['beef',
#   'tropical fruit',
#   'root vegetables',
#   'herbs',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'hard cheese',
#   'rolls/buns',
#   'brown bread',
#   'bottled water',
#   'bottled beer',
#   'salty snack'],
#  ['packaged fruit/vegetables'],
#  ['frankfurter',
#   'sausage',
#   'beef',
#   'root vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'dessert',
#   'yogurt',
#   'sliced cheese',
#   'ice cream',
#   'rolls/buns'],
#  ['berries', 'frozen vegetables', 'pet care'],
#  ['bottled water', 'soda', 'chewing gum'],
#  ['sausage',
#   'chicken',
#   'citrus fruit',
#   'berries',
#   'root vegetables',
#   'curd',
#   'beverages'],
#  ['whole milk',
#   'UHT-milk',
#   'domestic eggs',
#   'soda',
#   'fruit/vegetable juice',
#   'dishes'],
#  ['ice cream'],
#  ['frankfurter', 'citrus fruit', 'tropical fruit'],
#  ['root vegetables',
#   'whole milk',
#   'white bread',
#   'brown bread',
#   'sweet spreads',
#   'dog food',
#   'brandy'],
#  ['sausage', 'rolls/buns'],
#  ['sausage',
#   'ham',
#   'citrus fruit',
#   'tropical fruit',
#   'berries',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'sliced cheese',
#   'pastry',
#   'sugar'],
#  ['beef', 'root vegetables', 'whole milk'],
#  ['sugar'],
#  ['berries'],
#  ['yogurt', 'beverages'],
#  ['pork'],
#  ['bottled beer'],
#  ['curd', 'butter milk', 'yogurt', 'sliced cheese'],
#  ['beef', 'Instant food products'],
#  ['pork',
#   'berries',
#   'whipped/sour cream',
#   'beverages',
#   'flour',
#   'oil',
#   'soda',
#   'chocolate'],
#  ['grapes', 'whole milk', 'processed cheese', 'rolls/buns', 'white bread'],
#  ['potato products'],
#  ['root vegetables',
#   'onions',
#   'yogurt',
#   'rolls/buns',
#   'coffee',
#   'bottled water'],
#  ['chicken',
#   'hamburger meat',
#   'UHT-milk',
#   'soda',
#   'canned beer',
#   'bathroom cleaner'],
#  ['chicken', 'other vegetables'],
#  ['fish', 'cream cheese'],
#  ['other vegetables',
#   'whole milk',
#   'frozen meals',
#   'rolls/buns',
#   'brown bread'],
#  ['chicken',
#   'pork',
#   'whole milk',
#   'frozen vegetables',
#   'brown bread',
#   'vinegar',
#   'bottled beer',
#   'red/blush wine'],
#  ['other vegetables'],
#  ['tropical fruit'],
#  ['whole milk', 'cake bar'],
#  ['beef', 'hamburger meat', 'berries', 'pastry'],
#  ['sausage', 'grapes', 'rolls/buns', 'soda'],
#  ['whole milk', 'rolls/buns'],
#  ['rolls/buns'],
#  ['citrus fruit', 'tropical fruit', 'pip fruit'],
#  ['whole milk',
#   'sliced cheese',
#   'domestic eggs',
#   'artif. sweetener',
#   'bottled water',
#   'soda'],
#  ['pastry', 'soda'],
#  ['tropical fruit',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'soft cheese',
#   'hard cheese',
#   'spread cheese',
#   'curd cheese',
#   'frozen vegetables',
#   'ice cream',
#   'pastry',
#   'coffee',
#   'fruit/vegetable juice'],
#  ['sliced cheese', 'pastry'],
#  ['ham',
#   'citrus fruit',
#   'whole milk',
#   'dessert',
#   'frozen meals',
#   'coffee',
#   'popcorn'],
#  ['whole milk',
#   'curd',
#   'cream cheese',
#   'flour',
#   'coffee',
#   'bottled water',
#   'misc. beverages'],
#  ['root vegetables'],
#  ['soda', 'canned beer'],
#  ['curd',
#   'roll products',
#   'margarine',
#   'bottled water',
#   'canned beer',
#   'white wine'],
#  ['bottled water', 'soda', 'fruit/vegetable juice', 'bottled beer'],
#  ['packaged fruit/vegetables'],
#  ['tropical fruit',
#   'root vegetables',
#   'frozen vegetables',
#   'ice cream',
#   'bottled water'],
#  ['ham',
#   'beef',
#   'grapes',
#   'yogurt',
#   'whipped/sour cream',
#   'domestic eggs',
#   'white bread',
#   'pastry',
#   'bottled water',
#   'fruit/vegetable juice',
#   'white wine',
#   'salty snack',
#   'chocolate',
#   'newspapers'],
#  ['pork',
#   'citrus fruit',
#   'UHT-milk',
#   'brown bread',
#   'soda',
#   'bottled beer',
#   'canned beer'],
#  ['beverages', 'rolls/buns', 'soda', 'misc. beverages', 'liqueur'],
#  ['sausage', 'rolls/buns'],
#  ['sausage',
#   'citrus fruit',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'bottled water',
#   'soda'],
#  ['root vegetables',
#   'whole milk',
#   'butter',
#   'yogurt',
#   'cream cheese',
#   'frozen fish'],
#  ['whole milk'],
#  ['frankfurter',
#   'turkey',
#   'root vegetables',
#   'other vegetables',
#   'yogurt',
#   'rolls/buns',
#   'pastry'],
#  ['soda'],
#  ['soda'],
#  ['frankfurter'],
#  ['berries',
#   'whole milk',
#   'whipped/sour cream',
#   'pickled vegetables',
#   'detergent'],
#  ['frankfurter', 'pork', 'white bread', 'canned vegetables'],
#  ['frankfurter',
#   'hamburger meat',
#   'whole milk',
#   'butter',
#   'curd',
#   'flour',
#   'rice',
#   'oil',
#   'sugar',
#   'mustard',
#   'salty snack',
#   'chocolate',
#   'chocolate marshmallow',
#   'dish cleaner'],
#  ['berries',
#   'root vegetables',
#   'whole milk',
#   'beverages',
#   'sugar',
#   'soups',
#   'coffee'],
#  ['frankfurter'],
#  ['frozen fish'],
#  ['tropical fruit'],
#  ['beef',
#   'grapes',
#   'berries',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'newspapers'],
#  ['rolls/buns', 'coffee', 'instant coffee', 'salty snack'],
#  ['specialty chocolate'],
#  ['sparkling wine'],
#  ['citrus fruit', 'napkins'],
#  ['onions', 'herbs'],
#  ['whole milk', 'pastry', 'detergent'],
# ...
#   'whole milk',
#   'yogurt',
#   'cream cheese',
#   'frozen dessert',
#   'sugar',
#   'meat spreads',
#   'soda'],
#  ['frankfurter',
#   'pip fruit',
#   'root vegetables',
#   'curd',
#   'yogurt',
#   'UHT-milk',
#   'white bread',
#   'pastry',
#   'instant coffee',
#   'waffles'],
#  ['grapes', 'other vegetables', 'whole milk', 'butter', 'toilet cleaner'],
#  ['sausage',
#   'grapes',
#   'butter',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'beverages',
#   'UHT-milk',
#   'sliced cheese',
#   'processed cheese',
#   'rolls/buns',
#   'pastry'],
#  ['citrus fruit', 'white bread', 'liquor', 'specialty bar'],
#  ['ham',
#   'butter',
#   'yogurt',
#   'hard cheese',
#   'ice cream',
#   'domestic eggs',
#   'misc. beverages'],
#  ['beef',
#   'tropical fruit',
#   'pip fruit',
#   'grapes',
#   'root vegetables',
#   'processed cheese',
#   'rolls/buns',
#   'white bread',
#   'pastry',
#   'pasta',
#   'specialty vegetables',
#   'cat food',
#   'soda'],
#  ['other vegetables',
#   'whole milk',
#   'yogurt',
#   'specialty cheese',
#   'cereals',
#   'bottled beer'],
#  ['frankfurter',
#   'sausage',
#   'ham',
#   'other vegetables',
#   'domestic eggs',
#   'rolls/buns',
#   'pastry',
#   'long life bakery product',
#   'specialty bar'],
#  ['sausage',
#   'other vegetables',
#   'whole milk',
#   'sliced cheese',
#   'white bread',
#   'baking powder',
#   'pickled vegetables'],
#  ['bottled water',
#   'soda',
#   'fruit/vegetable juice',
#   'long life bakery product',
#   'chewing gum'],
#  ['bottled water'],
#  ['bottled water', 'soda'],
#  ['chicken',
#   'beef',
#   'whole milk',
#   'curd',
#   'brown bread',
#   'pastry',
#   'sauces',
#   'pickled vegetables',
#   'bottled water',
#   'soda',
#   'salty snack',
#   'waffles',
#   'specialty bar',
#   'napkins'],
#  ['frankfurter',
#   'tropical fruit',
#   'dessert',
#   'pastry',
#   'flour',
#   'margarine',
#   'sugar',
#   'artif. sweetener',
#   'sauces',
#   'rum'],
#  ['chicken',
#   'citrus fruit',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'hard cheese',
#   'processed cheese',
#   'mayonnaise',
#   'frozen vegetables',
#   'pastry',
#   'roll products',
#   'rice',
#   'margarine',
#   'sugar',
#   'pickled vegetables',
#   'bottled water',
#   'fruit/vegetable juice',
#   'candy',
#   'skin care'],
#  ['chicken',
#   'tropical fruit',
#   'whole milk',
#   'condensed milk',
#   'soft cheese',
#   'processed cheese',
#   'domestic eggs',
#   'white bread',
#   'pastry',
#   'semi-finished bread',
#   'soda',
#   'long life bakery product',
#   'waffles',
#   'specialty chocolate',
#   'napkins',
#   'dishes',
#   'kitchen towels'],
#  ['butter', 'rolls/buns', 'pastry', 'bottled water', 'canned beer'],
#  ['citrus fruit', 'root vegetables', 'dessert', 'yogurt', 'UHT-milk'],
#  ['whipped/sour cream', 'beverages'],
#  ['frankfurter', 'turkey'],
#  ['beef',
#   'citrus fruit',
#   'other vegetables',
#   'whole milk',
#   'domestic eggs',
#   'rolls/buns',
#   'brown bread',
#   'coffee',
#   'soda',
#   'salty snack'],
#  ['chicken', 'other vegetables', 'white wine'],
#  ['sausage',
#   'finished products',
#   'tropical fruit',
#   'pip fruit',
#   'other vegetables',
#   'butter',
#   'curd',
#   'dessert',
#   'butter milk',
#   'yogurt',
#   'whipped/sour cream',
#   'soft cheese',
#   'frozen vegetables',
#   'rolls/buns',
#   'white bread',
#   'brown bread',
#   'pastry',
#   'pasta',
#   'soups',
#   'baby food',
#   'fruit/vegetable juice',
#   'salty snack',
#   'waffles',
#   'cake bar',
#   'chocolate'],
#  ['citrus fruit',
#   'whole milk',
#   'butter',
#   'dessert',
#   'UHT-milk',
#   'flower (seeds)'],
#  ['ice cream', 'coffee'],
#  ['frankfurter',
#   'herbs',
#   'yogurt',
#   'UHT-milk',
#   'mayonnaise',
#   'frozen vegetables',
#   'margarine',
#   'bottled water',
#   'soda',
#   'salty snack',
#   'seasonal products',
#   'detergent'],
#  ['UHT-milk', 'vinegar', 'waffles'],
#  ['UHT-milk',
#   'domestic eggs',
#   'brown bread',
#   'coffee',
#   'soda',
#   'canned beer',
#   'liquor (appetizer)'],
#  ['citrus fruit', 'butter', 'UHT-milk', 'margarine'],
#  ['sausage',
#   'hamburger meat',
#   'tropical fruit',
#   'onions',
#   'other vegetables',
#   'butter',
#   'yogurt',
#   'white bread',
#   'brown bread',
#   'margarine'],
#  ['frankfurter',
#   'root vegetables',
#   'other vegetables',
#   'domestic eggs',
#   'rolls/buns',
#   'pastry',
#   'soups',
#   'Instant food products'],
#  ['citrus fruit',
#   'yogurt',
#   'UHT-milk',
#   'cream cheese',
#   'dish cleaner',
#   'house keeping products'],
#  ['ham',
#   'whole milk',
#   'processed cheese',
#   'white bread',
#   'semi-finished bread',
#   'bottled water',
#   'soda',
#   'fruit/vegetable juice',
#   'popcorn',
#   'chewing gum'],
#  ['ham',
#   'chicken',
#   'citrus fruit',
#   'pip fruit',
#   'herbs',
#   'other vegetables',
#   'butter'],
#  ['bottled water'],
#  ['popcorn'],
#  ['tropical fruit', 'pip fruit', 'other vegetables', 'cream cheese', 'soda'],
#  ['frankfurter',
#   'sausage',
#   'UHT-milk',
#   'frozen meals',
#   'frozen dessert',
#   'domestic eggs',
#   'rolls/buns',
#   'pastry',
#   'mustard'],
#  ['hamburger meat',
#   'citrus fruit',
#   'packaged fruit/vegetables',
#   'rolls/buns',
#   'vinegar',
#   'cocoa drinks'],
#  ['soda'],
#  ['sausage', 'root vegetables', 'rolls/buns', 'bottled water', 'white wine'],
#  ['yogurt',
#   'sliced cheese',
#   'frozen vegetables',
#   'frozen meals',
#   'pickled vegetables',
#   'coffee'],
#  ['meat',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'soft cheese',
#   'sliced cheese',
#   'domestic eggs',
#   'margarine',
#   'cat food',
#   'pet care',
#   'coffee',
#   'bottled beer',
#   'red/blush wine',
#   'dish cleaner',
#   'napkins'],
#  ['UHT-milk'],
#  ['whole milk', 'soda', 'misc. beverages'],
#  ['cat food', 'dish cleaner'],
#  ['citrus fruit',
#   'tropical fruit',
#   'pip fruit',
#   'grapes',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'dessert',
#   'whipped/sour cream',
#   'UHT-milk',
#   'frozen vegetables',
#   'frozen meals',
#   'bottled water',
#   'fruit/vegetable juice',
#   'specialty chocolate'],
#  ['citrus fruit',
#   'other vegetables',
#   'butter',
#   'soda',
#   'bottled beer',
#   'canned beer',
#   'waffles',
#   'chocolate'],
#  ['meat',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'cream cheese',
#   'margarine',
#   'bottled water'],
#  ['root vegetables', 'whipped/sour cream', 'salt', 'fruit/vegetable juice'],
#  ['tropical fruit',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'whipped/sour cream'],
#  ['brown bread', 'oil', 'sugar', 'soda'],
#  ['grapes', 'brown bread', 'bottled beer'],
#  ['ham', 'tropical fruit', 'cream cheese', 'processed cheese', 'white bread'],
#  ['root vegetables'],
#  ['ice cream', 'misc. beverages', 'canned beer', 'napkins'],
#  ['tropical fruit', 'other vegetables', 'bottled water', 'bottled beer'],
#  ['finished products', 'other vegetables', 'soda'],
#  ['other vegetables', 'yogurt', 'oil'],
#  ['other vegetables'],
#  ['dessert', 'yogurt', 'UHT-milk', 'soda', 'canned beer'],
#  ['frankfurter',
#   'tropical fruit',
#   'cream cheese',
#   'rolls/buns',
#   'fruit/vegetable juice',
#   'kitchen towels'],
#  ['sausage',
#   'citrus fruit',
#   'pip fruit',
#   'yogurt',
#   'beverages',
#   'sliced cheese',
#   'sugar',
#   'bottled water',
#   'soda'],
#  ['meat',
#   'citrus fruit',
#   'root vegetables',
#   'other vegetables',
#   'whipped/sour cream',
#   'semi-finished bread'],
#  ['sausage', 'yogurt', 'pastry', 'margarine', 'soda', 'bottled beer'],
#  ['beef',
#   'citrus fruit',
#   'onions',
#   'herbs',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'whipped/sour cream',
#   'specialty cheese',
#   'brown bread',
#   'canned vegetables',
#   'bottled water',
#   'dish cleaner',
#   'abrasive cleaner'],
#  ['pip fruit',
#   'other vegetables',
#   'butter',
#   'yogurt',
#   'whipped/sour cream',
#   'brown bread',
#   'pastry',
#   'fruit/vegetable juice'],
#  ['ham',
#   'hamburger meat',
#   'onions',
#   'other vegetables',
#   'processed cheese',
#   'frozen vegetables',
#   'domestic eggs',
#   'rolls/buns',
#   'white bread',
#   'cookware'],
#  ['yogurt'],
#  ['citrus fruit', 'grapes', 'curd', 'bottled water'],
#  ['other vegetables'],
#  ['pork', 'frozen meals', 'frozen fish'],
#  ['ham',
#   'grapes',
#   'spread cheese',
#   'ice cream',
#   'frozen potato products',
#   'white bread',
#   'oil'],
#  ['grapes',
#   'specialty cheese',
#   'pasta',
#   'coffee',
#   'bottled water',
#   'soda',
#   'canned beer',
#   'brandy'],
#  ['citrus fruit', 'bottled water', 'red/blush wine'],
#  ['dessert'],
#  ['citrus fruit', 'tropical fruit', 'pip fruit'],
#  ['root vegetables', 'sliced cheese', 'soda'],
#  ['pork'],
#  ['turkey', 'whole milk', 'UHT-milk'],
#  ['tropical fruit', 'other vegetables', 'soda', 'candy'],
#  ['sausage',
#   'other vegetables',
#   'pasta',
#   'oil',
#   'margarine',
#   'coffee',
#   'syrup',
#   'canned beer',
#   'napkins',
#   'light bulbs'],
#  ['sausage',
#   'meat',
#   'other vegetables',
#   'brown bread',
#   'canned fish',
#   'bottled water',
#   'canned beer',
#   'liquor (appetizer)'],
#  ['pork',
#   'tropical fruit',
#   'other vegetables',
#   'dessert',
#   'yogurt',
#   'roll products',
#   'flour',
#   'rice',
#   'coffee',
#   'bottled water',
#   'soda',
#   'fruit/vegetable juice',
#   'canned beer'],
#  ['sausage', 'citrus fruit', 'pip fruit', 'mayonnaise', 'brown bread'],
#  ['grapes', 'chocolate'],
#  ['grapes', 'pastry', 'salty snack', 'light bulbs'],
#  ['other vegetables',
#   'yogurt',
#   'processed cheese',
#   'ketchup',
#   'bottled water'],
#  ['bottled water'],
#  ['prosecco', 'hygiene articles'],
#  ['UHT-milk', 'soda', 'dish cleaner'],
#  ['bottled water', 'soda', 'chewing gum', 'specialty chocolate'],
#  ['rolls/buns', 'canned fish'],
#  ['beef',
#   'other vegetables',
#   'butter milk',
#   'yogurt',
#   'whipped/sour cream',
#   'cream cheese',
#   'white bread',
#   'fruit/vegetable juice',
#   'bottled beer'],
#  ['tropical fruit', 'pasta'],
#  ['beef',
#   'root vegetables',
#   'other vegetables',
#   'butter',
#   'yogurt',
#   'rolls/buns'],
#  ['rolls/buns'],
#  ['berries', 'root vegetables', 'whipped/sour cream', 'roll products'],
#  ['sausage',
#   'hamburger meat',
#   'whole milk',
#   'rolls/buns',
#   'oil',
#   'pickled vegetables',
#   'softener'],
#  ['chicken', 'pork', 'beef', 'whole milk', 'curd'],
#  ['sausage',
#   'citrus fruit',
#   'whole milk',
#   'cream cheese',
#   'processed cheese',
#   'frozen vegetables',
#   'rolls/buns',
#   'pastry',
#   'fruit/vegetable juice'],
#  ['soda'],
#  ['yogurt', 'UHT-milk'],
#  ['rolls/buns', 'red/blush wine'],
#  ['rolls/buns'],
#  ['whole milk'],
#  ['citrus fruit',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'hard cheese',
#   'cream cheese',
#   'domestic eggs',
#   'flour',
#   'rice',
#   'oil',
#   'margarine'],
#  ['citrus fruit', 'tropical fruit', 'grapes', 'whole milk', 'brown bread'],
#  ['brown bread'],
#  ['tropical fruit',
#   'other vegetables',
#   'whipped/sour cream',
#   'UHT-milk',
#   'frozen vegetables',
#   'oil',
#   'margarine',
#   'fruit/vegetable juice'],
#  ['frankfurter',
#   'tropical fruit',
#   'butter',
#   'whipped/sour cream',
#   'frozen vegetables',
#   'rolls/buns',
#   'sugar',
#   'baking powder',
#   'bottled water',
#   'misc. beverages',
#   'long life bakery product'],
#  ['ham', 'rolls/buns', 'bottled beer'],
#  ['other vegetables', 'curd', 'yogurt', 'pickled vegetables'],
#  ['sausage', 'whole milk', 'curd', 'butter milk'],
#  ['pork', 'whole milk', 'margarine', 'soda', 'canned beer'],
#  ['citrus fruit', 'yogurt', 'whipped/sour cream', 'soda'],
#  ['tropical fruit', 'whole milk', 'domestic eggs', 'pastry'],
#  ['other vegetables', 'yogurt'],
#  ['pork', 'whole milk', 'sugar', 'soda', 'long life bakery product'],
#  ['chicken',
#   'pork',
#   'pip fruit',
#   'other vegetables',
#   'whole milk',
#   'tidbits',
#   'frozen fish',
#   'rolls/buns',
#   'margarine',
#   'baking powder',
#   'soda',
#   'bottled beer',
#   'white wine',
#   'waffles',
#   'chocolate'],
#  ['root vegetables', 'whole milk', 'yogurt', 'rolls/buns'],
#  ['citrus fruit', 'cake bar', 'baby cosmetics'],
#  ['beef', 'tropical fruit', 'whole milk', 'ice cream'],
#  ['frankfurter',
#   'sausage',
#   'liver loaf',
#   'ham',
#   'chicken',
#   'beef',
#   'citrus fruit',
#   'tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'beverages',
#   'soft cheese',
#   'hard cheese',
#   'cream cheese',
#   'mayonnaise',
#   'domestic eggs',
#   'rolls/buns',
#   'roll products',
#   'flour',
#   'pasta',
#   'margarine',
#   'specialty fat',
#   'sugar',
#   'soups',
#   'skin care',
#   'hygiene articles'],
#  ['frankfurter',
#   'pip fruit',
#   'other vegetables',
#   'yogurt',
#   'spread cheese',
#   'rolls/buns',
#   'white bread',
#   'pastry',
#   'coffee',
#   'soda',
#   'waffles'],
#  ['beef',
#   'hamburger meat',
#   'other vegetables',
#   'rolls/buns',
#   'brown bread',
#   'bottled water',
#   'soda',
#   'bottled beer'],
#  ['ham',
#   'pork',
#   'hamburger meat',
#   'pip fruit',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'curd',
#   'dessert',
#   'butter milk',
#   'whipped/sour cream',
#   'domestic eggs',
#   'brown bread',
#   'roll products'],
#  ['pork',
#   'root vegetables',
#   'other vegetables',
#   'specialty fat',
#   'sugar',
#   'baking powder',
#   'cat food',
#   'salty snack',
#   'waffles'],
#  ['condensed milk', 'bottled water', 'misc. beverages', 'bottled beer'],
#  ['chicken', 'bottled beer', 'red/blush wine'],
#  ['sausage', 'meat', 'butter', 'domestic eggs'],
#  ['bottled beer'],
#  ['chicken',
#   'pork',
#   'grapes',
#   'other vegetables',
#   'domestic eggs',
#   'rolls/buns',
#   'pastry',
#   'soda'],
#  ['finished products',
#   'other vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'margarine',
#   'cereals',
#   'soda'],
#  ['pork',
#   'beef',
#   'citrus fruit',
#   'berries',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'cream cheese',
#   'vinegar',
#   'oil',
#   'cat food',
#   'specialty chocolate',
#   'detergent',
#   'dish cleaner',
#   'abrasive cleaner',
#   'cleaner',
#   'hygiene articles'],
#  ['root vegetables', 'whole milk', 'yogurt'],
#  ['domestic eggs', 'seasonal products'],
#  ['domestic eggs', 'specialty bar', 'seasonal products'],
#  ['bottled water'],
#  ['other vegetables',
#   'rolls/buns',
#   'bottled water',
#   'fruit/vegetable juice',
#   'canned beer',
#   'whisky'],
#  ['sausage',
#   'meat',
#   'pork',
#   'whole milk',
#   'butter',
#   'whipped/sour cream',
#   'frozen vegetables',
#   'frozen dessert',
#   'white bread',
#   'brown bread',
#   'pastry'],
#  ['sausage', 'mayonnaise', 'rolls/buns', 'canned beer'],
#  ['tropical fruit', 'sliced cheese', 'domestic eggs'],
#  ['frankfurter',
#   'beef',
#   'tropical fruit',
#   'pip fruit',
#   'butter',
#   'yogurt',
#   'dog food',
#   'long life bakery product',
#   'cookware'],
#  ['frozen potato products'],
#  ['frankfurter', 'sausage', 'packaged fruit/vegetables'],
#  ['frankfurter', 'other vegetables'],
#  ['chicken',
#   'tropical fruit',
#   'pip fruit',
#   'root vegetables',
#   'herbs',
#   'other vegetables',
#   'dessert',
#   'yogurt',
#   'whipped/sour cream',
#   'beverages',
#   'brown bread',
#   'cat food'],
#  ['tropical fruit',
#   'pip fruit',
#   'other vegetables',
#   'whole milk',
#   'napkins',
#   'dishes'],
#  ['citrus fruit', 'grapes', 'rolls/buns', 'pastry', 'coffee'],
#  ['hamburger meat',
#   'pip fruit',
#   'whole milk',
#   'curd',
#   'beverages',
#   'brandy',
#   'male cosmetics',
#   'cookware'],
#  ['chicken', 'berries', 'mayonnaise', 'frozen vegetables', 'salty snack'],
#  ['sausage',
#   'tropical fruit',
#   'whole milk',
#   'yogurt',
#   'processed cheese',
#   'pastry',
#   'margarine',
#   'Instant food products',
#   'coffee',
#   'popcorn'],
#  ['frozen potato products', 'bottled water'],
#  ['frankfurter',
#   'whole milk',
#   'whipped/sour cream',
#   'curd cheese',
#   'domestic eggs',
#   'margarine',
#   'baking powder',
#   'cat food',
#   'bottled water',
#   'canned beer',
#   'candy'],
#  ['sausage',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'whipped/sour cream',
#   'processed cheese',
#   'sugar',
#   'baking powder',
#   'jam',
#   'coffee',
#   'bottled water',
#   'soda',
#   'fruit/vegetable juice',
#   'salty snack',
#   'long life bakery product',
#   'candy'],
#  ['tropical fruit', 'dessert', 'sweet spreads'],
#  ['rolls/buns'],
#  ['citrus fruit', 'tropical fruit', 'whole milk'],
#  ['yogurt'],
#  ['turkey',
#   'pork',
#   'beef',
#   'hamburger meat',
#   'tropical fruit',
#   'root vegetables',
#   'onions',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'butter milk',
#   'yogurt',
#   'rolls/buns',
#   'oil',
#   'fruit/vegetable juice',
#   'waffles'],
#  ['soda'],
#  ['sausage', 'other vegetables'],
#  ['pork',
#   'root vegetables',
#   'whole milk',
#   'curd',
#   'whipped/sour cream',
#   'rolls/buns',
#   'white bread',
#   'canned vegetables',
#   'soda'],
#  ...]

# %%
columns = set([]) # empty set since set skip the same entries
for l in data: # a list in data
    for e in l: # a element in list
        columns.add(e)
columns = list(columns) # convert set to list to easy iterate
columns = sorted(columns) # sort elements by alphabetical order
columns
# Out:
# ['Instant food products',
#  'UHT-milk',
#  'abrasive cleaner',
#  'artif. sweetener',
#  'baby cosmetics',
#  'baby food',
#  'baking powder',
#  'bathroom cleaner',
#  'beef',
#  'berries',
#  'beverages',
#  'bottled beer',
#  'bottled water',
#  'brandy',
#  'brown bread',
#  'butter',
#  'butter milk',
#  'cake bar',
#  'candles',
#  'candy',
#  'canned beer',
#  'canned fish',
#  'canned fruit',
#  'canned vegetables',
#  'cat food',
#  'cereals',
#  'chewing gum',
#  'chicken',
#  'chocolate',
#  'chocolate marshmallow',
#  'citrus fruit',
#  'cleaner',
#  'cling film/bags',
#  'cocoa drinks',
#  'coffee',
#  'condensed milk',
#  'cooking chocolate',
#  'cookware',
#  'cream',
#  'cream cheese',
#  'curd',
#  'curd cheese',
#  'decalcifier',
#  'dental care',
#  'dessert',
#  'detergent',
#  'dish cleaner',
#  'dishes',
#  'dog food',
#  'domestic eggs',
#  'female sanitary products',
#  'finished products',
#  'fish',
#  'flour',
#  'flower (seeds)',
#  'flower soil/fertilizer',
#  'frankfurter',
#  'frozen chicken',
#  'frozen dessert',
#  'frozen fish',
#  'frozen fruits',
#  'frozen meals',
#  'frozen potato products',
#  'frozen vegetables',
#  'fruit/vegetable juice',
#  'grapes',
#  'hair spray',
#  'ham',
#  'hamburger meat',
#  'hard cheese',
#  'herbs',
#  'honey',
#  'house keeping products',
#  'hygiene articles',
#  'ice cream',
#  'instant coffee',
#  'jam',
#  'ketchup',
#  'kitchen towels',
#  'kitchen utensil',
#  'light bulbs',
#  'liqueur',
#  'liquor',
#  'liquor (appetizer)',
#  'liver loaf',
#  'long life bakery product',
#  'make up remover',
#  'male cosmetics',
#  'margarine',
#  'mayonnaise',
#  'meat',
#  'meat spreads',
#  'misc. beverages',
#  'mustard',
#  'napkins',
#  'newspapers',
#  'nut snack',
#  'nuts/prunes',
#  'oil',
#  'onions',
#  'organic products',
#  'organic sausage',
#  'other vegetables',
#  'packaged fruit/vegetables',
#  'pasta',
#  'pastry',
#  'pet care',
#  'photo/film',
#  'pickled vegetables',
#  'pip fruit',
#  'popcorn',
#  'pork',
#  'potato products',
#  'potted plants',
#  'preservation products',
#  'processed cheese',
#  'prosecco',
#  'pudding powder',
#  'ready soups',
#  'red/blush wine',
#  'rice',
#  'roll products',
#  'rolls/buns',
#  'root vegetables',
#  'rubbing alcohol',
#  'rum',
#  'salad dressing',
#  'salt',
#  'salty snack',
#  'sauces',
#  'sausage',
#  'seasonal products',
#  'semi-finished bread',
#  'skin care',
#  'sliced cheese',
#  'snack products',
#  'soap',
#  'soda',
#  'soft cheese',
#  'softener',
#  'sound storage medium',
#  'soups',
#  'sparkling wine',
#  'specialty bar',
#  'specialty cheese',
#  'specialty chocolate',
#  'specialty fat',
#  'specialty vegetables',
#  'spices',
#  'spread cheese',
#  'sugar',
#  'sweet spreads',
#  'syrup',
#  'tea',
#  'tidbits',
#  'toilet cleaner',
#  'tropical fruit',
#  'turkey',
#  'vinegar',
#  'waffles',
#  'whipped/sour cream',
#  'whisky',
#  'white bread',
#  'white wine',
#  'whole milk',
#  'yogurt',
#  'zwieback']

# %%
bool_data = []
for l in data: # a list in data
    temp = []
    for c in columns: # every column in columns
        if c in l: # if column is in the list
            temp.append(True) # append the value True 
        else:
            temp.append(False) # append the value False
    bool_data.append(temp)

# %%
data = pd.DataFrame(bool_data, columns = columns) # creating data frame

# %%
data.head()
# Out:
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
# 2                  False     False             False             False
# 3                  False     False             False             False
# 4                  False     False             False             False
#
#    baby cosmetics  baby food  baking powder  bathroom cleaner   beef  berries  \
# 0           False      False          False             False  False    False
# 1           False      False          False             False  False    False
# 2           False      False          False             False  False    False
# 3           False      False          False             False  False    False
# 4           False      False          False             False  False    False
#
#    ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0  ...   False    False    False               False   False        False
# 1  ...   False    False    False               False   False        False
# 2  ...   False    False    False               False   False        False
# 3  ...   False    False    False               False   False        False
# 4  ...   False    False    False               False   False        False
#
#    white wine  whole milk  yogurt  zwieback
# 0       False       False   False     False
# 1       False       False    True     False
# 2       False       False    True     False
# 3       False        True   False     False
# 4       False        True    True     False
#
# [5 rows x 167 columns]

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.dtypes
# Out:
# Instant food products    bool
# UHT-milk                 bool
# abrasive cleaner         bool
# artif. sweetener         bool
# baby cosmetics           bool
#                          ...
# white bread              bool
# white wine               bool
# whole milk               bool
# yogurt                   bool
# zwieback                 bool
# Length: 167, dtype: object

# %% [markdown]
# <font color=SpringGreen><h1>Apriori cells</h1></font>

# %%
apr = apriori(df = data, min_support = 0.05, use_colnames = True)
apr
# Out:
#      support                             itemsets
# 0   0.063445                               (beef)
# 1   0.053153                       (bottled beer)
# 2   0.108520                      (bottled water)
# 3   0.068395                        (brown bread)
# 4   0.068265                             (butter)
# 5   0.053022                            (chicken)
# 6   0.103179                       (citrus fruit)
# 7   0.053022                             (coffee)
# 8   0.064878                               (curd)
# 9   0.073476                      (domestic eggs)
# 10  0.074127                        (frankfurter)
# 11  0.055107                  (frozen vegetables)
# 12  0.065399              (fruit/vegetable juice)
# 13  0.062923                          (margarine)
# 14  0.230849                   (other vegetables)
# 15  0.092626                             (pastry)
# 16  0.091454                          (pip fruit)
# 17  0.070219                               (pork)
# 18  0.190464                         (rolls/buns)
# 19  0.134315                    (root vegetables)
# 20  0.117118                            (sausage)
# 21  0.148124                               (soda)
# 22  0.130146                     (tropical fruit)
# 23  0.081813                 (whipped/sour cream)
# 24  0.301199                         (whole milk)
# 25  0.163106                             (yogurt)
# 26  0.058755  (other vegetables, root vegetables)
# 27  0.093147       (whole milk, other vegetables)
# 28  0.052762           (other vegetables, yogurt)
# 29  0.063705             (whole milk, rolls/buns)
# 30  0.060448        (whole milk, root vegetables)
# 31  0.052241         (whole milk, tropical fruit)
# 32  0.068265                 (whole milk, yogurt)

# %%
# %timeit -n 10 -r 1 apriori(df = data, min_support = 0.05, use_colnames = True)
# Out:
# 13.2 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 10 loops each)

# %%
ar = association_rules(apr, min_threshold=0.3)
ar
# Out:
#           antecedents         consequents  antecedent support  \
# 0   (root vegetables)  (other vegetables)            0.134315
# 1        (whole milk)  (other vegetables)            0.301199
# 2  (other vegetables)        (whole milk)            0.230849
# 3            (yogurt)  (other vegetables)            0.163106
# 4        (rolls/buns)        (whole milk)            0.190464
# 5   (root vegetables)        (whole milk)            0.134315
# 6    (tropical fruit)        (whole milk)            0.130146
# 7            (yogurt)        (whole milk)            0.163106
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.230849  0.058755    0.437439  1.894912  0.027748    1.367231
# 1            0.230849  0.093147    0.309256  1.339644  0.023616    1.113510
# 2            0.301199  0.093147    0.403499  1.339644  0.023616    1.171501
# 3            0.230849  0.052762    0.323482  1.401270  0.015109    1.136926
# 4            0.301199  0.063705    0.334473  1.110475  0.006338    1.049998
# 5            0.301199  0.060448    0.450048  1.494192  0.019993    1.270660
# 6            0.301199  0.052241    0.401401  1.332680  0.013041    1.167396
# 7            0.301199  0.068265    0.418530  1.389550  0.019137    1.201785

# %% [markdown]
# <font color=SpringGreen><h1>FP Growth tree cells</h1></font>

# %%
fp = fpgrowth(data, min_support = 0.05, use_colnames = True)
fp
# Out:
#      support                             itemsets
# 0   0.103179                       (citrus fruit)
# 1   0.062923                          (margarine)
# 2   0.163106                             (yogurt)
# 3   0.130146                     (tropical fruit)
# 4   0.091454                          (pip fruit)
# 5   0.301199                         (whole milk)
# 6   0.230849                   (other vegetables)
# 7   0.068265                             (butter)
# 8   0.190464                         (rolls/buns)
# 9   0.053153                       (bottled beer)
# 10  0.108520                      (bottled water)
# 11  0.064878                               (curd)
# 12  0.074127                        (frankfurter)
# 13  0.053022                            (chicken)
# 14  0.065399              (fruit/vegetable juice)
# 15  0.134315                    (root vegetables)
# 16  0.148124                               (soda)
# 17  0.117118                            (sausage)
# 18  0.068395                        (brown bread)
# 19  0.081813                 (whipped/sour cream)
# 20  0.070219                               (pork)
# 21  0.063445                               (beef)
# 22  0.092626                             (pastry)
# 23  0.073476                      (domestic eggs)
# 24  0.053022                             (coffee)
# 25  0.055107                  (frozen vegetables)
# 26  0.068265                 (whole milk, yogurt)
# 27  0.052762           (other vegetables, yogurt)
# 28  0.052241         (whole milk, tropical fruit)
# 29  0.093147       (whole milk, other vegetables)
# 30  0.063705             (whole milk, rolls/buns)
# 31  0.058755  (other vegetables, root vegetables)
# 32  0.060448        (whole milk, root vegetables)

# %%
# %timeit -n 10 -r 1 fpgrowth(data, min_support = 0.05, use_colnames = True)
# Out:
# 90.7 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 10 loops each)
